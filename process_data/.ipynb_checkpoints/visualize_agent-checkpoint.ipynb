# %%
import base64
from IPython.display import HTML

base_dir = '/home/sethlinc/projects/honours-dopamine/dopamine/agent_viz/Pong/dqn'
video = open('{}/images/video.mp4'.format(base_dir), 'rb').read()
encoded = base64.b64encode(video)
HTML(data='''<video alt="test" controls><source src="data:video/mp4;base64,{0}" type="video/mp4" /></video>'''.format(encoded.decode('ascii')))
# Out:
# <video alt="test" controls><source src="data:video/mp4;base64,..." type="video/mp4" /></video>
